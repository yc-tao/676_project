# %% [markdown]
# # RQ1 DLNM PoC Demo
#
# Runs the marginal exposure-outcome DLNM sweep and displays the ranked summary.

# %%
from rq1_dlnm.run_sweep import run
import pandas as pd
summary = run()
summary.head(20)
# Out:
# /Users/yichentao/GitHub/676_project/.worktrees/rq1-dlnm/src/rq1_dlnm/data.py:83: RuntimeWarning: All-NaN slice encountered
#   med = np.nanmedian(row)
# /Users/yichentao/GitHub/676_project/.worktrees/rq1-dlnm/src/rq1_dlnm/data.py:83: RuntimeWarning: All-NaN slice encountered
#   med = np.nanmedian(row)
# /Users/yichentao/GitHub/676_project/.worktrees/rq1-dlnm/src/rq1_dlnm/data.py:83: RuntimeWarning: All-NaN slice encountered
#   med = np.nanmedian(row)
# /Users/yichentao/GitHub/676_project/.worktrees/rq1-dlnm/src/rq1_dlnm/data.py:83: RuntimeWarning: All-NaN slice encountered
#   med = np.nanmedian(row)
# /Users/yichentao/GitHub/676_project/.worktrees/rq1-dlnm/src/rq1_dlnm/data.py:83: RuntimeWarning: All-NaN slice encountered
#   med = np.nanmedian(row)
# /Users/yichentao/GitHub/676_project/.worktrees/rq1-dlnm/src/rq1_dlnm/data.py:83: RuntimeWarning: All-NaN slice encountered
#   med = np.nanmedian(row)
# /Users/yichentao/GitHub/676_project/.worktrees/rq1-dlnm/src/rq1_dlnm/data.py:83: RuntimeWarning: All-NaN slice encountered
#   med = np.nanmedian(row)
# /Users/yichentao/GitHub/676_project/.worktrees/rq1-dlnm/src/rq1_dlnm/data.py:83: RuntimeWarning: All-NaN slice encountered
#   med = np.nanmedian(row)
#                                         exposure  chapter    log_rr        se  \
# 0   total_aerosol_optical_depth_at_550nm_surface  J00-J99 -0.827342  0.040074
# 1   total_aerosol_optical_depth_at_550nm_surface  I00-I99 -0.281459  0.052084
# 2   total_aerosol_optical_depth_at_550nm_surface  F01-F99 -0.005464  0.047204
# 3   total_aerosol_optical_depth_at_550nm_surface  E00-E89 -0.349623  0.043519
# 4   particulate_matter_d_less_than_25_um_surface  J00-J99  0.485216  0.012809
# 5   particulate_matter_d_less_than_25_um_surface  I00-I99 -0.239148  0.016443
# 6   particulate_matter_d_less_than_25_um_surface  F01-F99 -0.087593  0.014448
# 7   particulate_matter_d_less_than_25_um_surface  E00-E89  0.043796  0.013553
# 8                      NO2_column_number_density  J00-J99 -0.128732  0.002902
# 9                      NO2_column_number_density  I00-I99  0.160193  0.003981
# 10                     NO2_column_number_density  F01-F99 -0.166507  0.003385
# 11                     NO2_column_number_density  E00-E89 -0.027825  0.003196
# 12                                         ozone  J00-J99 -0.402961  0.092310
# 13                                         ozone  I00-I99 -0.615910  0.118959
# 14                                         ozone  F01-F99 -0.431886  0.104458
# 15                                         ozone  E00-E89 -0.560558  0.097903
# 16                                temperature_2m  J00-J99 -1.693041  0.121148
# 17                                temperature_2m  I00-I99  0.914426  0.154795
# 18                                temperature_2m  F01-F99  0.969074  0.139485
# 19                                temperature_2m  E00-E89  0.270480  0.133904
#
#                p             q  converged
# 0   0.000000e+00  0.000000e+00      False
# 1   6.520088e-08  8.188017e-08      False
# 2   9.078404e-01  9.337787e-01       True
# 3   8.881784e-16  1.314017e-15       True
# 4   0.000000e+00  0.000000e+00      False
# 5   0.000000e+00  0.000000e+00      False
# 6   1.337736e-09  1.805944e-09      False
# 7   1.231131e-03  1.399601e-03      False
# 8   0.000000e+00  0.000000e+00      False
# 9   0.000000e+00  0.000000e+00      False
# 10  0.000000e+00  0.000000e+00      False
# 11  0.000000e+00  0.000000e+00      False
# 12  1.269364e-05  1.506497e-05       True
# 13  2.248712e-07  2.791504e-07       True
# 14  3.556614e-05  4.130262e-05       True
# 15  1.030256e-08  1.340574e-08       True
# 16  0.000000e+00  0.000000e+00      False
# 17  3.476547e-09  4.578866e-09      False
# 18  3.718137e-12  5.283668e-12      False
# 19  4.338722e-02  4.685820e-02      False

# %%
from pathlib import Path
from IPython.display import Image, display
for p in sorted(Path('results/figures').glob('*.png'))[:6]:
    display(Image(str(p)))
